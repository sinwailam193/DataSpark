# %% [markdown]
# ### 🔗 Links and Resources
# - [withColumn()](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.withColumn.html)
# - [withColumns()](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.withColumns.html)

# %% [markdown]
# ### 📌 Reading data into a Spark DataFrame

# %%
df = spark.read.table("population_metrics.default.countries_population")

# %% [markdown]
# ### 📌 withColumn()

# %%
from pyspark.sql.functions import upper

# withColumn adds single columns or replaces the existing column with the same name

df.withColumn("country_name", upper("name")).\
  withColumn("population_density", df.population / df.area_km2).\
  select("coutry_name", "population", "area_km2","population_density").\
  display()

# %% [markdown]
# #### It's often more efficient to use a single select() method.
#
# Chaining withColumn() and select() result in multiple DataFrames

# %%
df.select(
      df.name.alias("country_name"), 
      df.population, 
      df.area_km2,
      (df.population / df.area_km2).alias("population_density").\
  display()

# %% [markdown]
# ### 📌 withColumns()

# %%
# withColumns adds multiple columns or replaces the existing columns that have the same names

df.withColumns(
  {
    "country_name": upper("name"), 
    "population_density": df.population / df.area_km2
    }
  ).display()
