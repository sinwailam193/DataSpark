# %% [markdown]
# ### 🔗 Links and Resources
# - [Databricks Runtime release notes versions and compatibility](https://learn.microsoft.com/en-us/azure/databricks/release-notes/runtime/)
# - [Python Downloads](https://www.python.org/downloads/)
# - [Java Downloads](https://www.oracle.com/uk/java/technologies/downloads/)
# - [Visual Studio Code Download](https://code.visualstudio.com/download)
# - [Visual Studio Code Tutorial](https://code.visualstudio.com/docs/introvideos/basics)
# - [Local Development Tools](https://learn.microsoft.com/en-us/azure/databricks/dev-tools/)
# - [Git Download](https://git-scm.com/downloads)
# - [GitHub](https://git-scm.com/downloads)
# - [GitHub Getting Started](https://docs.github.com/en/get-started/start-your-journey/hello-world)
# - [Configure Git credentials & connect a remote repo to Databricks](https://learn.microsoft.com/en-us/azure/databricks/repos/get-access-tokens-from-git-provider)
# - [Databricks Git Folders](https://learn.microsoft.com/en-us/azure/databricks/repos/)
