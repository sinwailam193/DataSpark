# %% [markdown]
# ### 🔗 Links and Resources
#
# ##### Unity Catalog and Metastore Management
# - [What is Unity Catalog?](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/)
# - [Manage your Databricks Account](https://learn.microsoft.com/en-us/azure/databricks/admin/account-settings/)
# - [Data Discovery](https://learn.microsoft.com/en-us/azure/databricks/discover/)
# - [Data Lineage](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/data-lineage)
# - [System Tables](https://learn.microsoft.com/en-us/azure/databricks/admin/system-tables/)
# - [Admin privileges in Unity Catalog](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/manage-privileges/admin-privileges)
# - [Unity Catalog privileges and securable objects](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/manage-privileges/privileges)
# - [Inheritance](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/manage-privileges/#inheritance)
# - [Workspace-Catalog Binding](https://learn.microsoft.com/en-us/azure/databricks/catalogs/binding)
# - [Azure built-in roles](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles)
# - [Legacy Hive Metastore vs Unity Catalog](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/hive-metastore#access-control-in-unity-catalog-compared-to-the-legacy-hive-metastore)
# - [Create a Metastore](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/create-metastore)
# - [Managed vs External Volumes](https://learn.microsoft.com/en-us/azure/databricks/volumes/managed-vs-external)
#
# ##### Workspace ACLs
# - [Access Control Lists (ACLs)](https://learn.microsoft.com/en-us/azure/databricks/security/auth/access-control/)
# - [Users and Groups](https://learn.microsoft.com/en-us/azure/databricks/admin/users-groups/)
# - [Compute Policies](https://learn.microsoft.com/en-us/azure/databricks/admin/clusters/policies)
#
# ##### Accessing External Data
# - [abfss URI](https://learn.microsoft.com/en-us/azure/storage/blobs/data-lake-storage-introduction-abfs-uri)
# - [Configure a Managed Identity with Access Connector for Azure Databricks](https://learn.microsoft.com/en-us/azure/databricks/connect/unity-catalog/cloud-storage/azure-managed-identities#config-managed-id)
# - [Create a storage credential for connecting to Azure Data Lake Storage](https://learn.microsoft.com/en-us/azure/databricks/connect/unity-catalog/cloud-storage/storage-credentials)
# - [Create an external location to connect cloud storage to Azure Databricks](https://learn.microsoft.com/en-us/azure/databricks/connect/unity-catalog/cloud-storage/external-locations#catalog-explorer)
